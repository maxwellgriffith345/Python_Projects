# %%
import numpy as np
import pandas as pd
import os

# %%
xlsx = pd.ExcelFile('ExcelExp4-2.xlsx')

# %%
data1 = pd.read_excel(xlsx)

# %%
data1.info
# Out:
# <bound method DataFrame.info of      CustomerID                 CompanyName                           Address  \
# 0         EASTC          Eastern Connection                    35 King George
# 1         EASTC          Eastern Connection                    35 King George
# 2         EASTC          Eastern Connection                    35 King George
# 3         RATTC  Rattlesnake Canyon Grocery                   2817 Milton Dr.
# 4         RATTC  Rattlesnake Canyon Grocery                   2817 Milton Dr.
# ...         ...                         ...                               ...
# 1054      THEBI              The Big Cheese  89 Jefferson Way_x000D_\nSuite 2
# 1055      VICTE        Victuailles en stock                2, rue du Commerce
# 1056      VICTE        Victuailles en stock                2, rue du Commerce
# 1057      VICTE        Victuailles en stock                2, rue du Commerce
# 1058      FRANS              Franchi S.p.A.               Via Monte Bianco 34
#
# ...

# %%
data1.head()
# Out:
#   CustomerID                 CompanyName          Address         City  \
# 0      EASTC          Eastern Connection   35 King George       London
# 1      EASTC          Eastern Connection   35 King George       London
# 2      EASTC          Eastern Connection   35 King George       London
# 3      RATTC  Rattlesnake Canyon Grocery  2817 Milton Dr.  Albuquerque
# 4      RATTC  Rattlesnake Canyon Grocery  2817 Milton Dr.  Albuquerque
#
#   State/Province PostalCode Country/Region    Salesperson  OrderID  OrderDate  \
# 0            NaN    WX3 6FW             UK  Nancy Davolio    10400 2020-01-01
# 1            NaN    WX3 6FW             UK  Nancy Davolio    10400 2020-01-01
# 2            NaN    WX3 6FW             UK  Nancy Davolio    10400 2020-01-01
# 3             NM      87110            USA  Nancy Davolio    10401 2020-01-01
# 4             NM      87110            USA  Nancy Davolio    10401 2020-01-01
#
#    ... Discount ExtendedPrice Freight                    ShipName  \
# ...

# %%
pd.options.display.max_rows = 28

# %%
data1.fillna('NA')
# Out:
#      CustomerID                 CompanyName                           Address  \
# 0         EASTC          Eastern Connection                    35 King George
# 1         EASTC          Eastern Connection                    35 King George
# 2         EASTC          Eastern Connection                    35 King George
# 3         RATTC  Rattlesnake Canyon Grocery                   2817 Milton Dr.
# 4         RATTC  Rattlesnake Canyon Grocery                   2817 Milton Dr.
# ...         ...                         ...                               ...
# 1054      THEBI              The Big Cheese  89 Jefferson Way_x000D_\nSuite 2
# 1055      VICTE        Victuailles en stock                2, rue du Commerce
# 1056      VICTE        Victuailles en stock                2, rue du Commerce
# 1057      VICTE        Victuailles en stock                2, rue du Commerce
# 1058      FRANS              Franchi S.p.A.               Via Monte Bianco 34
#
# ...

# %%
data1['Country/Region'].value_counts()
# Out:
# Germany        170
# USA            170
# Brazil         106
# France          93
# UK              75
# Austria         60
# Venezuela       51
# Sweden          45
# Canada          43
# Finland         35
# Mexico          34
# Denmark         29
# Italy           28
# Ireland         26
# Switzerland     25
# Belgium         19
# Portugal        18
# Argentina       12
# Spain           11
# Poland           6
# Norway           3
# Name: Country/Region, dtype: int64

# %%
data1.head()
# Out:
#   CustomerID                 CompanyName          Address         City  \
# 0      EASTC          Eastern Connection   35 King George       London
# 1      EASTC          Eastern Connection   35 King George       London
# 2      EASTC          Eastern Connection   35 King George       London
# 3      RATTC  Rattlesnake Canyon Grocery  2817 Milton Dr.  Albuquerque
# 4      RATTC  Rattlesnake Canyon Grocery  2817 Milton Dr.  Albuquerque
#
#   State/Province PostalCode Country/Region    Salesperson  OrderID  OrderDate  \
# 0            NaN    WX3 6FW             UK  Nancy Davolio    10400 2020-01-01
# 1            NaN    WX3 6FW             UK  Nancy Davolio    10400 2020-01-01
# 2            NaN    WX3 6FW             UK  Nancy Davolio    10400 2020-01-01
# 3             NM      87110            USA  Nancy Davolio    10401 2020-01-01
# 4             NM      87110            USA  Nancy Davolio    10401 2020-01-01
#
#    ... Discount ExtendedPrice Freight                    ShipName  \
# ...

# %%
USA_index = data1['Country/Region']=='USA'

# %%
USA_index
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1054     True
# 1055    False
# 1056    False
# 1057    False
# 1058    False
# Name: Country/Region, Length: 1059, dtype: bool

# %%
dataUSA = data1[USA_index]

# %%
dataUSA
# Out:
#      CustomerID                 CompanyName  \
# 3         RATTC  Rattlesnake Canyon Grocery
# 4         RATTC  Rattlesnake Canyon Grocery
# 5         RATTC  Rattlesnake Canyon Grocery
# 6         RATTC  Rattlesnake Canyon Grocery
# 39        HUNGC  Hungry Coyote Import Store
# ...         ...                         ...
# 949       RATTC  Rattlesnake Canyon Grocery
# 981       THECR             The Cracker Box
# 982       THECR             The Cracker Box
# 1053      THEBI              The Big Cheese
# 1054      THEBI              The Big Cheese
#
#                                      Address         City State/Province  \
# 3                            2817 Milton Dr.  Albuquerque             NM
# 4                            2817 Milton Dr.  Albuquerque             NM
# 5                            2817 Milton Dr.  Albuquerque             NM
# 6                            2817 Milton Dr.  Albuquerque             NM
# ...

# %%
dataUSA.loc[4] #get row
# Out:
# CustomerID                             RATTC
# CompanyName       Rattlesnake Canyon Grocery
# Address                      2817 Milton Dr.
# City                             Albuquerque
# State/Province                            NM
# PostalCode                             87110
# Country/Region                           USA
# Salesperson                    Nancy Davolio
# OrderID                                10401
# OrderDate                2020-01-01 00:00:00
# RequiredDate             2020-01-29 00:00:00
# ShippedDate              2020-01-10 00:00:00
# Shipper                       Speedy Express
# ProductID                                 56
# ProductName           Gnocchi di nonna Alice
# Category                      Grains/Cereals
# UnitPrice                               30.4
# Quantity                                  70
# Discount                                 0.0
# ExtendedPrice                         2128.0
# Freight                                12.51
# ...

# %%
dataUSA.isnull() #show null
# Out:
#       CustomerID  CompanyName  Address   City  State/Province  PostalCode  \
# 3          False        False    False  False           False       False
# 4          False        False    False  False           False       False
# 5          False        False    False  False           False       False
# 6          False        False    False  False           False       False
# 39         False        False    False  False           False       False
# ...          ...          ...      ...    ...             ...         ...
# 949        False        False    False  False           False       False
# 981        False        False    False  False           False       False
# 982        False        False    False  False           False       False
# 1053       False        False    False  False           False       False
# 1054       False        False    False  False           False       False
#
#       Country/Region  Salesperson  OrderID  OrderDate  ...  Discount  \
# ...

# %%
#passing a list to value_counts()
dataUSA[['PostalCode', 'Salesperson']].value_counts()
# Out:
# PostalCode  Salesperson
# 83720       Steven Buchanan     13
#             Michael Suyama      11
#             Laura Callahan      10
#             Nancy Davolio        9
# 98128       Margaret Peacock     8
#                                 ..
# 97219       Janet Leverling      1
# 97827       Laura Callahan       1
# 99362       Laura Callahan       1
#             Nancy Davolio        1
# 97403       Laura Callahan       1
# Length: 44, dtype: int64

# %%
#number of sales per person at each zip code % of total sales 
dataUSA[['PostalCode','Salesperson']].value_counts(normalize=True)
# Out:
# PostalCode  Salesperson
# 83720       Steven Buchanan     0.076471
#             Michael Suyama      0.064706
#             Laura Callahan      0.058824
#             Nancy Davolio       0.052941
# 98128       Margaret Peacock    0.047059
#                                   ...
# 97219       Janet Leverling     0.005882
# 97827       Laura Callahan      0.005882
# 99362       Laura Callahan      0.005882
#             Nancy Davolio       0.005882
# 97403       Laura Callahan      0.005882
# Length: 44, dtype: float64

# %%
dataUSA.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'Address', 'City', 'State/Province',
#        'PostalCode', 'Country/Region', 'Salesperson', 'OrderID', 'OrderDate',
#        'RequiredDate', 'ShippedDate', 'Shipper', 'ProductID', 'ProductName',
#        'Category', 'UnitPrice', 'Quantity', 'Discount', 'ExtendedPrice',
#        'Freight', 'ShipName', 'ShipAddress', 'ShipCity', 'ShipRegion',
#        'ShipPostalCode', 'ShipCountry', 'Unnamed: 27'],
#       dtype='object')

# %%
#show a count of null values in each column
data1.isnull().sum()
# Out:
# CustomerID           0
# CompanyName          0
# Address              0
# City                 0
# State/Province     651
# PostalCode          26
# Country/Region       0
# Salesperson          0
# OrderID              0
# OrderDate            0
# RequiredDate         0
# ShippedDate          0
# Shipper              0
# ProductID            0
# ProductName          0
# Category             0
# UnitPrice            0
# Quantity             0
# Discount             0
# ExtendedPrice        0
# Freight              0
# ShipName             0
# ShipAddress          0
# ShipCity             0
# ShipRegion         633
# ShipPostalCode      26
# ShipCountry          0
# Unnamed: 27       1059
# dtype: int64

# %%
#delete null roll
del data1['Unnamed: 27']

# %%
data1.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'Address', 'City', 'State/Province',
#        'PostalCode', 'Country/Region', 'Salesperson', 'OrderID', 'OrderDate',
#        'RequiredDate', 'ShippedDate', 'Shipper', 'ProductID', 'ProductName',
#        'Category', 'UnitPrice', 'Quantity', 'Discount', 'ExtendedPrice',
#        'Freight', 'ShipName', 'ShipAddress', 'ShipCity', 'ShipRegion',
#        'ShipPostalCode', 'ShipCountry'],
#       dtype='object')

# %%
dataUSA.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'Address', 'City', 'State/Province',
#        'PostalCode', 'Country/Region', 'Salesperson', 'OrderID', 'OrderDate',
#        'RequiredDate', 'ShippedDate', 'Shipper', 'ProductID', 'ProductName',
#        'Category', 'UnitPrice', 'Quantity', 'Discount', 'ExtendedPrice',
#        'Freight', 'ShipName', 'ShipAddress', 'ShipCity', 'ShipRegion',
#        'ShipPostalCode', 'ShipCountry', 'Unnamed: 27'],
#       dtype='object')

# %%
del dataUSA['Unnamed: 27'] #delete column

# %%
dataUSA.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'Address', 'City', 'State/Province',
#        'PostalCode', 'Country/Region', 'Salesperson', 'OrderID', 'OrderDate',
#        'RequiredDate', 'ShippedDate', 'Shipper', 'ProductID', 'ProductName',
#        'Category', 'UnitPrice', 'Quantity', 'Discount', 'ExtendedPrice',
#        'Freight', 'ShipName', 'ShipAddress', 'ShipCity', 'ShipRegion',
#        'ShipPostalCode', 'ShipCountry'],
#       dtype='object')

# %%
#drop a column
USA = dataUSA.drop('Country/Region', axis=1)

# %%
USA.head()
# Out:
#    CustomerID                 CompanyName  \
# 3       RATTC  Rattlesnake Canyon Grocery
# 4       RATTC  Rattlesnake Canyon Grocery
# 5       RATTC  Rattlesnake Canyon Grocery
# 6       RATTC  Rattlesnake Canyon Grocery
# 39      HUNGC  Hungry Coyote Import Store
#
#                                    Address         City State/Province  \
# 3                          2817 Milton Dr.  Albuquerque             NM
# 4                          2817 Milton Dr.  Albuquerque             NM
# 5                          2817 Milton Dr.  Albuquerque             NM
# 6                          2817 Milton Dr.  Albuquerque             NM
# 39  City Center Plaza_x000D_\n516 Main St.        Elgin             OR
#
#    PostalCode      Salesperson  OrderID  OrderDate RequiredDate  ... Quantity  \
# 3       87110    Nancy Davolio    10401 2020-01-01   2020-01-29  ...       18
# 4       87110    Nancy Davolio    10401 2020-01-01   2020-01-29  ...       70
# ...

# %%
USA.drop(3) #drop row
# Out:
#      CustomerID                 CompanyName  \
# 4         RATTC  Rattlesnake Canyon Grocery
# 5         RATTC  Rattlesnake Canyon Grocery
# 6         RATTC  Rattlesnake Canyon Grocery
# 39        HUNGC  Hungry Coyote Import Store
# 40        HUNGC  Hungry Coyote Import Store
# ...         ...                         ...
# 949       RATTC  Rattlesnake Canyon Grocery
# 981       THECR             The Cracker Box
# 982       THECR             The Cracker Box
# 1053      THEBI              The Big Cheese
# 1054      THEBI              The Big Cheese
#
#                                      Address         City State/Province  \
# 4                            2817 Milton Dr.  Albuquerque             NM
# 5                            2817 Milton Dr.  Albuquerque             NM
# 6                            2817 Milton Dr.  Albuquerque             NM
# 39    City Center Plaza_x000D_\n516 Main St.        Elgin             OR
# ...

# %%
USA.index
# Out:
# Int64Index([   3,    4,    5,    6,   39,   40,   83,   84,  103,  104,
#             ...
#              937,  938,  939,  940,  948,  949,  981,  982, 1053, 1054],
#            dtype='int64', length=170)

# %%
USA.index.name

# %%
USA.iloc[3]
# Out:
# CustomerID                             RATTC
# CompanyName       Rattlesnake Canyon Grocery
# Address                      2817 Milton Dr.
# City                             Albuquerque
# State/Province                            NM
# PostalCode                             87110
# Salesperson                    Nancy Davolio
# OrderID                                10401
# OrderDate                2020-01-01 00:00:00
# RequiredDate             2020-01-29 00:00:00
# ShippedDate              2020-01-10 00:00:00
# Shipper                       Speedy Express
# ProductID                                 71
# ProductName                      Fløtemysost
# Category                      Dairy Products
# UnitPrice                               17.2
# Quantity                                  60
# Discount                                 0.0
# ExtendedPrice                         1032.0
# Freight                                12.51
# ShipName          Rattlesnake Canyon Grocery
# ...

# %%
USA.iloc[3:6]
# Out:
#    CustomerID                 CompanyName  \
# 6       RATTC  Rattlesnake Canyon Grocery
# 39      HUNGC  Hungry Coyote Import Store
# 40      HUNGC  Hungry Coyote Import Store
#
#                                    Address         City State/Province  \
# 6                          2817 Milton Dr.  Albuquerque             NM
# 39  City Center Plaza_x000D_\n516 Main St.        Elgin             OR
# 40  City Center Plaza_x000D_\n516 Main St.        Elgin             OR
#
#    PostalCode      Salesperson  OrderID  OrderDate RequiredDate  ... Quantity  \
# 6       87110    Nancy Davolio    10401 2020-01-01   2020-01-29  ...       60
# 39      97827  Janet Leverling    10415 2020-01-15   2020-02-12  ...        2
# 40      97827  Janet Leverling    10415 2020-01-15   2020-02-12  ...       20
#
#    Discount  ExtendedPrice Freight                    ShipName  \
# 6       0.0         1032.0   12.51  Rattlesnake Canyon Grocery
# ...

# %%
USA.iloc[:][USA.Quantity>10] #orders quantity over 10
# Out:
#     CustomerID                 CompanyName  \
# 3        RATTC  Rattlesnake Canyon Grocery
# 4        RATTC  Rattlesnake Canyon Grocery
# 5        RATTC  Rattlesnake Canyon Grocery
# 6        RATTC  Rattlesnake Canyon Grocery
# 40       HUNGC  Hungry Coyote Import Store
# ..         ...                         ...
# 937      SAVEA          Save-a-lot Markets
# 939      SAVEA          Save-a-lot Markets
# 940      SAVEA          Save-a-lot Markets
# 948      RATTC  Rattlesnake Canyon Grocery
# 949      RATTC  Rattlesnake Canyon Grocery
#
#                                     Address         City State/Province  \
# 3                           2817 Milton Dr.  Albuquerque             NM
# 4                           2817 Milton Dr.  Albuquerque             NM
# 5                           2817 Milton Dr.  Albuquerque             NM
# 6                           2817 Milton Dr.  Albuquerque             NM
# 40   City Center Plaza_x000D_\n516 Main St.        Elgin             OR
# ...

# %%
USA['State/Province'].value_counts()
# Out:
# ID    64
# WA    32
# OR    30
# NM    17
# AK     9
# CA     7
# WY     6
# MT     5
# Name: State/Province, dtype: int64

# %%
WestCoast_States = ['WA','OR','CA']

# %%
#List only west coast states
#USA.iloc[:][USA['State/Province'] in WestCoast_States] #doesn't work

# %%
'WA' in WestCoast_States
# Out:
# True

# %%
#USA.iloc[:][lambda x: x['State/Province'] in WestCoast_States] #still doesn't work

# %%
#df.loc[df['column_name'].isin(some_values)]

# %%
USA.loc[USA['State/Province'].isin(WestCoast_States)] #loc for boolean
# Out:
#      CustomerID                 CompanyName  \
# 39        HUNGC  Hungry Coyote Import Store
# 40        HUNGC  Hungry Coyote Import Store
# 183       WHITC        White Clover Markets
# 184       WHITC        White Clover Markets
# 185       WHITC        White Clover Markets
# ...         ...                         ...
# 890       WHITC        White Clover Markets
# 891       WHITC        White Clover Markets
# 892       WHITC        White Clover Markets
# 1053      THEBI              The Big Cheese
# 1054      THEBI              The Big Cheese
#
#                                      Address      City State/Province  \
# 39    City Center Plaza_x000D_\n516 Main St.     Elgin             OR
# 40    City Center Plaza_x000D_\n516 Main St.     Elgin             OR
# 183      305 - 14th Ave. S._x000D_\nSuite 3B   Seattle             WA
# 184      305 - 14th Ave. S._x000D_\nSuite 3B   Seattle             WA
# 185      305 - 14th Ave. S._x000D_\nSuite 3B   Seattle             WA
# ...
