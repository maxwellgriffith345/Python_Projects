# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import requests, bs4, csv
import os

# %%
#parsing web content html
url = 'https://www.formula1.com/en/results.html/2021/races/1067/monaco.html'

# %%
tables = pd.read_html(url)
monaco=tables[0]
monaco
# Out:
#     Unnamed: 0 Pos  No                    Driver                        Car  \
# 0          NaN   1  33      Max  Verstappen  VER      Red Bull Racing Honda
# 1          NaN   2  55        Carlos  Sainz  SAI                    Ferrari
# 2          NaN   3   4        Lando  Norris  NOR           McLaren Mercedes
# 3          NaN   4  11        Sergio  Perez  PER      Red Bull Racing Honda
# 4          NaN   5   5    Sebastian  Vettel  VET      Aston Martin Mercedes
# 5          NaN   6  10        Pierre  Gasly  GAS           AlphaTauri Honda
# 6          NaN   7  44      Lewis  Hamilton  HAM                   Mercedes
# 7          NaN   8  18        Lance  Stroll  STR      Aston Martin Mercedes
# 8          NaN   9  31        Esteban  Ocon  OCO             Alpine Renault
# 9          NaN  10  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 10         NaN  11   7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari
# 11         NaN  12   3    Daniel  Ricciardo  RIC           McLaren Mercedes
# 12         NaN  13  14     Fernando  Alonso  ALO             Alpine Renault
# 13         NaN  14  63      George  Russell  RUS          Williams Mercedes
# 14         NaN  15   6     Nicholas  Latifi  LAT          Williams Mercedes
# 15         NaN  16  22        Yuki  Tsunoda  TSU           AlphaTauri Honda
# 16         NaN  17   9      Nikita  Mazepin  MAZ               Haas Ferrari
# 17         NaN  18  47     Mick  Schumacher  MSC               Haas Ferrari
# 18         NaN  NC  77     Valtteri  Bottas  BOT                   Mercedes
# 19         NaN  NC  16     Charles  Leclerc  LEC                    Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     78  1:38:56.820   25         NaN
# 1     78      +8.968s   18         NaN
# 2     78     +19.427s   15         NaN
# 3     78     +20.490s   12         NaN
# 4     78     +52.591s   10         NaN
# 5     78     +53.896s    8         NaN
# 6     78     +68.231s    7         NaN
# 7     77       +1 lap    4         NaN
# 8     77       +1 lap    2         NaN
# 9     77       +1 lap    1         NaN
# 10    77       +1 lap    0         NaN
# 11    77       +1 lap    0         NaN
# 12    77       +1 lap    0         NaN
# 13    77       +1 lap    0         NaN
# 14    77       +1 lap    0         NaN
# 15    77       +1 lap    0         NaN
# 16    75      +3 laps    0         NaN
# 17    75      +3 laps    0         NaN
# 18    29          DNF    0         NaN
# 19     0          DNS    0         NaN

# %%
stripurl=url.lstrip('https://www.formula1.com/en/results.html/').rstrip('.html')

# %%
stripurl
# Out:
# '2021/races/1067/monaco'

# %%
spliturl = stripurl.split('/')
spliturl
# Out:
# ['2021', 'races', '1067', 'monaco']

# %%
year_race = (spliturl[0], spliturl[3])
year_race
# Out:
# ('2021', 'monaco')

# %%
#issue years with race in same location 2020 austria and styria have the same url country

# %%
monaco['year']= '2021'
monaco
# Out:
#     Unnamed: 0 Pos  No                    Driver                        Car  \
# 0          NaN   1  33      Max  Verstappen  VER      Red Bull Racing Honda
# 1          NaN   2  55        Carlos  Sainz  SAI                    Ferrari
# 2          NaN   3   4        Lando  Norris  NOR           McLaren Mercedes
# 3          NaN   4  11        Sergio  Perez  PER      Red Bull Racing Honda
# 4          NaN   5   5    Sebastian  Vettel  VET      Aston Martin Mercedes
# 5          NaN   6  10        Pierre  Gasly  GAS           AlphaTauri Honda
# 6          NaN   7  44      Lewis  Hamilton  HAM                   Mercedes
# 7          NaN   8  18        Lance  Stroll  STR      Aston Martin Mercedes
# 8          NaN   9  31        Esteban  Ocon  OCO             Alpine Renault
# 9          NaN  10  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 10         NaN  11   7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari
# 11         NaN  12   3    Daniel  Ricciardo  RIC           McLaren Mercedes
# 12         NaN  13  14     Fernando  Alonso  ALO             Alpine Renault
# 13         NaN  14  63      George  Russell  RUS          Williams Mercedes
# 14         NaN  15   6     Nicholas  Latifi  LAT          Williams Mercedes
# 15         NaN  16  22        Yuki  Tsunoda  TSU           AlphaTauri Honda
# 16         NaN  17   9      Nikita  Mazepin  MAZ               Haas Ferrari
# 17         NaN  18  47     Mick  Schumacher  MSC               Haas Ferrari
# 18         NaN  NC  77     Valtteri  Bottas  BOT                   Mercedes
# 19         NaN  NC  16     Charles  Leclerc  LEC                    Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8  year
# 0     78  1:38:56.820   25         NaN  2021
# 1     78      +8.968s   18         NaN  2021
# 2     78     +19.427s   15         NaN  2021
# 3     78     +20.490s   12         NaN  2021
# 4     78     +52.591s   10         NaN  2021
# 5     78     +53.896s    8         NaN  2021
# 6     78     +68.231s    7         NaN  2021
# 7     77       +1 lap    4         NaN  2021
# 8     77       +1 lap    2         NaN  2021
# 9     77       +1 lap    1         NaN  2021
# 10    77       +1 lap    0         NaN  2021
# 11    77       +1 lap    0         NaN  2021
# 12    77       +1 lap    0         NaN  2021
# 13    77       +1 lap    0         NaN  2021
# 14    77       +1 lap    0         NaN  2021
# 15    77       +1 lap    0         NaN  2021
# 16    75      +3 laps    0         NaN  2021
# 17    75      +3 laps    0         NaN  2021
# 18    29          DNF    0         NaN  2021
# 19     0          DNS    0         NaN  2021

# %%
monaco.drop(['year'], axis =1, inplace = True)
monaco
# Out:
#     Unnamed: 0 Pos  No                    Driver                        Car  \
# 0          NaN   1  33      Max  Verstappen  VER      Red Bull Racing Honda
# 1          NaN   2  55        Carlos  Sainz  SAI                    Ferrari
# 2          NaN   3   4        Lando  Norris  NOR           McLaren Mercedes
# 3          NaN   4  11        Sergio  Perez  PER      Red Bull Racing Honda
# 4          NaN   5   5    Sebastian  Vettel  VET      Aston Martin Mercedes
# 5          NaN   6  10        Pierre  Gasly  GAS           AlphaTauri Honda
# 6          NaN   7  44      Lewis  Hamilton  HAM                   Mercedes
# 7          NaN   8  18        Lance  Stroll  STR      Aston Martin Mercedes
# 8          NaN   9  31        Esteban  Ocon  OCO             Alpine Renault
# 9          NaN  10  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 10         NaN  11   7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari
# 11         NaN  12   3    Daniel  Ricciardo  RIC           McLaren Mercedes
# 12         NaN  13  14     Fernando  Alonso  ALO             Alpine Renault
# 13         NaN  14  63      George  Russell  RUS          Williams Mercedes
# 14         NaN  15   6     Nicholas  Latifi  LAT          Williams Mercedes
# 15         NaN  16  22        Yuki  Tsunoda  TSU           AlphaTauri Honda
# 16         NaN  17   9      Nikita  Mazepin  MAZ               Haas Ferrari
# 17         NaN  18  47     Mick  Schumacher  MSC               Haas Ferrari
# 18         NaN  NC  77     Valtteri  Bottas  BOT                   Mercedes
# 19         NaN  NC  16     Charles  Leclerc  LEC                    Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     78  1:38:56.820   25         NaN
# 1     78      +8.968s   18         NaN
# 2     78     +19.427s   15         NaN
# 3     78     +20.490s   12         NaN
# 4     78     +52.591s   10         NaN
# 5     78     +53.896s    8         NaN
# 6     78     +68.231s    7         NaN
# 7     77       +1 lap    4         NaN
# 8     77       +1 lap    2         NaN
# 9     77       +1 lap    1         NaN
# 10    77       +1 lap    0         NaN
# 11    77       +1 lap    0         NaN
# 12    77       +1 lap    0         NaN
# 13    77       +1 lap    0         NaN
# 14    77       +1 lap    0         NaN
# 15    77       +1 lap    0         NaN
# 16    75      +3 laps    0         NaN
# 17    75      +3 laps    0         NaN
# 18    29          DNF    0         NaN
# 19     0          DNS    0         NaN

# %%
#adding year race as a tuple?
monaco[['year', 'race']]=year_race

# %%
monaco
# Out:
#     Unnamed: 0 Pos  No                    Driver                        Car  \
# 0          NaN   1  33      Max  Verstappen  VER      Red Bull Racing Honda
# 1          NaN   2  55        Carlos  Sainz  SAI                    Ferrari
# 2          NaN   3   4        Lando  Norris  NOR           McLaren Mercedes
# 3          NaN   4  11        Sergio  Perez  PER      Red Bull Racing Honda
# 4          NaN   5   5    Sebastian  Vettel  VET      Aston Martin Mercedes
# 5          NaN   6  10        Pierre  Gasly  GAS           AlphaTauri Honda
# 6          NaN   7  44      Lewis  Hamilton  HAM                   Mercedes
# 7          NaN   8  18        Lance  Stroll  STR      Aston Martin Mercedes
# 8          NaN   9  31        Esteban  Ocon  OCO             Alpine Renault
# 9          NaN  10  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari
# 10         NaN  11   7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari
# 11         NaN  12   3    Daniel  Ricciardo  RIC           McLaren Mercedes
# 12         NaN  13  14     Fernando  Alonso  ALO             Alpine Renault
# 13         NaN  14  63      George  Russell  RUS          Williams Mercedes
# 14         NaN  15   6     Nicholas  Latifi  LAT          Williams Mercedes
# 15         NaN  16  22        Yuki  Tsunoda  TSU           AlphaTauri Honda
# 16         NaN  17   9      Nikita  Mazepin  MAZ               Haas Ferrari
# 17         NaN  18  47     Mick  Schumacher  MSC               Haas Ferrari
# 18         NaN  NC  77     Valtteri  Bottas  BOT                   Mercedes
# 19         NaN  NC  16     Charles  Leclerc  LEC                    Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8  year    race
# 0     78  1:38:56.820   25         NaN  2021  monaco
# 1     78      +8.968s   18         NaN  2021  monaco
# 2     78     +19.427s   15         NaN  2021  monaco
# 3     78     +20.490s   12         NaN  2021  monaco
# 4     78     +52.591s   10         NaN  2021  monaco
# 5     78     +53.896s    8         NaN  2021  monaco
# 6     78     +68.231s    7         NaN  2021  monaco
# 7     77       +1 lap    4         NaN  2021  monaco
# 8     77       +1 lap    2         NaN  2021  monaco
# 9     77       +1 lap    1         NaN  2021  monaco
# 10    77       +1 lap    0         NaN  2021  monaco
# 11    77       +1 lap    0         NaN  2021  monaco
# 12    77       +1 lap    0         NaN  2021  monaco
# 13    77       +1 lap    0         NaN  2021  monaco
# 14    77       +1 lap    0         NaN  2021  monaco
# 15    77       +1 lap    0         NaN  2021  monaco
# 16    75      +3 laps    0         NaN  2021  monaco
# 17    75      +3 laps    0         NaN  2021  monaco
# 18    29          DNF    0         NaN  2021  monaco
# 19     0          DNS    0         NaN  2021  monaco

# %%
monaco.drop(['Unnamed: 0','Unnamed: 8'], axis =1, inplace = True)
monaco
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-a03d86e1e1cf> in <module>
# ----> 1 monaco.drop(['Unnamed: 0','Unnamed: 8'], axis =1, inplace = True)
#       2 monaco
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0' 'Unnamed: 8'] not found in axis"

# %%
monaco
# Out:
#    Pos  No                    Driver                        Car  Laps  \
# 0    1  33      Max  Verstappen  VER      Red Bull Racing Honda    78
# 1    2  55        Carlos  Sainz  SAI                    Ferrari    78
# 2    3   4        Lando  Norris  NOR           McLaren Mercedes    78
# 3    4  11        Sergio  Perez  PER      Red Bull Racing Honda    78
# 4    5   5    Sebastian  Vettel  VET      Aston Martin Mercedes    78
# 5    6  10        Pierre  Gasly  GAS           AlphaTauri Honda    78
# 6    7  44      Lewis  Hamilton  HAM                   Mercedes    78
# 7    8  18        Lance  Stroll  STR      Aston Martin Mercedes    77
# 8    9  31        Esteban  Ocon  OCO             Alpine Renault    77
# 9   10  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari    77
# 10  11   7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari    77
# 11  12   3    Daniel  Ricciardo  RIC           McLaren Mercedes    77
# 12  13  14     Fernando  Alonso  ALO             Alpine Renault    77
# 13  14  63      George  Russell  RUS          Williams Mercedes    77
# 14  15   6     Nicholas  Latifi  LAT          Williams Mercedes    77
# 15  16  22        Yuki  Tsunoda  TSU           AlphaTauri Honda    77
# 16  17   9      Nikita  Mazepin  MAZ               Haas Ferrari    75
# 17  18  47     Mick  Schumacher  MSC               Haas Ferrari    75
# 18  NC  77     Valtteri  Bottas  BOT                   Mercedes    29
# 19  NC  16     Charles  Leclerc  LEC                    Ferrari     0
#
#    Time/Retired  PTS  year    race
# 0   1:38:56.820   25  2021  monaco
# 1       +8.968s   18  2021  monaco
# 2      +19.427s   15  2021  monaco
# 3      +20.490s   12  2021  monaco
# 4      +52.591s   10  2021  monaco
# 5      +53.896s    8  2021  monaco
# 6      +68.231s    7  2021  monaco
# 7        +1 lap    4  2021  monaco
# 8        +1 lap    2  2021  monaco
# 9        +1 lap    1  2021  monaco
# 10       +1 lap    0  2021  monaco
# 11       +1 lap    0  2021  monaco
# 12       +1 lap    0  2021  monaco
# 13       +1 lap    0  2021  monaco
# 14       +1 lap    0  2021  monaco
# 15       +1 lap    0  2021  monaco
# 16      +3 laps    0  2021  monaco
# 17      +3 laps    0  2021  monaco
# 18          DNF    0  2021  monaco
# 19          DNS    0  2021  monaco
