# %%
import requests,bs4, csv, os
import numpy as np
import pandas as pd
import f1scraper1 as scrape

# %%
main_url = 'https://www.formula1.com/en/results.html'
main_soup = scrape.get_soup(main_url)
year_links = scrape.get_year_links(main_soup) #get all year links

# %%
column_names = ['Drop1','Pos', 'No', 'Driver', 'Car', 'Laps', 'Time/Retired', 'PTS','Drop2'
       'race','date', 'circuit']
main_df = pd.DataFrame(columns = column_names)

# %%
years19_20 = year_links[1:3]
years19_20
# Out:
# ['https://www.formula1.com/en/results.html/2020/races.html',
#  'https://www.formula1.com/en/results.html/2019/races.html']

# %%
#SLOW AS SHIT
for year in years19_20:
    year_soup = scrape.get_soup(year)
    racelinks = scrape.get_race_links(year_soup)
    racelinks.pop(0)
    #racenames = scrape.get_race_names(year_soup)
    #name_link = list(zip(racenames,racelinks))
    for link in racelink:
        race_soup = scrape.get_soup(link)
        date_info = scrape.get_date_info(race_soup) #one call to parse
        name = scrape.get_race_name(race_soup)
        table = pd.read_html(link)
        df = table[0]
        #df.drop(['Unnamed: 0','Unnamed: 8'], axis =1, inplace = True) #drop these at the end
        df[['race','date','circuit']] = name,date,info
        main_df = main_df.append(df)

# %%
main_df.drop(['Unnamed: 0','Unnamed: 8'], axis =1, inplace = True)
# Out:
#    Pos  No                    Driver                        Car Laps  \
# 0    1  77     Valtteri  Bottas  BOT                   Mercedes   71
# 1    2  16     Charles  Leclerc  LEC                    Ferrari   71
# 2    3   4        Lando  Norris  NOR            McLaren Renault   71
# 3    4  44      Lewis  Hamilton  HAM                   Mercedes   71
# 4    5  55        Carlos  Sainz  SAI            McLaren Renault   71
# ..  ..  ..                       ...                        ...  ...
# 15  16  99  Antonio  Giovinazzi  GIO  Alfa Romeo Racing Ferrari   54
# 16  17  63      George  Russell  RUS          Williams Mercedes   54
# 17  18  10        Pierre  Gasly  GAS  Scuderia Toro Rosso Honda   53
# 18  19  88       Robert  Kubica  KUB          Williams Mercedes   53
# 19  NC  18        Lance  Stroll  STR  Racing Point BWT Mercedes   45
#
#    Time/Retired PTS       race         date                         circuit
# 0   1:30:55.739  25    Austria  05 Jul 2020        Red Bull Ring, Spielberg
# 1       +2.700s  18    Austria  05 Jul 2020        Red Bull Ring, Spielberg
# 2       +5.491s  16    Austria  05 Jul 2020        Red Bull Ring, Spielberg
# 3       +5.689s  12    Austria  05 Jul 2020        Red Bull Ring, Spielberg
# 4       +8.903s  10    Austria  05 Jul 2020        Red Bull Ring, Spielberg
# ..          ...  ..        ...          ...                             ...
# 15       +1 lap   0  Abu Dhabi  01 Dec 2019  Yas Marina Circuit, Yas Island
# 16       +1 lap   0  Abu Dhabi  01 Dec 2019  Yas Marina Circuit, Yas Island
# 17      +2 laps   0  Abu Dhabi  01 Dec 2019  Yas Marina Circuit, Yas Island
# 18      +2 laps   0  Abu Dhabi  01 Dec 2019  Yas Marina Circuit, Yas Island
# 19          DNF   0  Abu Dhabi  01 Dec 2019  Yas Marina Circuit, Yas Island
#
# [760 rows x 10 columns]

# %%
main_df.to_csv('raw_f1.csv', index =False)
