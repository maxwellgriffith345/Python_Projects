# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
data = pd.read_csv('Ham_Ver2020.csv', parse_dates = True)

# %%
data.head()
# Out:
#    DriverLast  PTS RaceCountry RaceDate        Circuit
# 0    Hamilton   12     Austria   7/5/20  Red Bull Ring
# 1  Verstappen    0     Austria   7/5/20  Red Bull Ring
# 2    Hamilton   25      Styria  7/12/20  Red Bull Ring
# 3  Verstappen   15      Styria  7/12/20  Red Bull Ring
# 4    Hamilton   26     Hungary  7/19/20    Hungaroring

# %%
sns.lineplot(data = data, x="RaceDate", y="PTS", hue = 'DriverLast')
# Out:
# <AxesSubplot:xlabel='RaceDate', ylabel='PTS'>

# %%
data.sort_values(by = 'RaceDate')
# Out:
#     DriverLast  PTS       RaceCountry  RaceDate  \
# 21  Verstappen   19             Eifel  10/11/20
# 20    Hamilton   25             Eifel  10/11/20
# 22    Hamilton   26          Portugal  10/25/20
# 23  Verstappen   15          Portugal  10/25/20
# 24    Hamilton   26    Emilia Romagna   11/1/20
# 25  Verstappen    0    Emilia Romagna   11/1/20
# 27  Verstappen    8            Turkey  11/15/20
# 26    Hamilton   25            Turkey  11/15/20
# 29  Verstappen   19           Bahrain  11/29/20
# 28    Hamilton   25           Bahrain  11/29/20
# 32    Hamilton   15         Abu Dhabi  12/13/20
# 31  Verstappen   25         Abu Dhabi  12/13/20
# 30  Verstappen    0            Sakhir   12/6/20
# 3   Verstappen   15            Styria   7/12/20
# 2     Hamilton   25            Styria   7/12/20
# 4     Hamilton   26           Hungary   7/19/20
# 5   Verstappen   18           Hungary   7/19/20
# 0     Hamilton   12           Austria    7/5/20
# ...

# %%
sns.lineplot(data = data, x="RaceDate", y="PTS", hue = 'DriverLast')
# Out:
# <AxesSubplot:xlabel='RaceDate', ylabel='PTS'>

# %%
data['TotalPTS'] = data.groupby(['DriverLast'])['PTS'].cumsum()

# %%
data
# Out:
#     DriverLast  PTS       RaceCountry  RaceDate  \
# 0     Hamilton   12           Austria    7/5/20
# 1   Verstappen    0           Austria    7/5/20
# 2     Hamilton   25            Styria   7/12/20
# 3   Verstappen   15            Styria   7/12/20
# 4     Hamilton   26           Hungary   7/19/20
# 5   Verstappen   18           Hungary   7/19/20
# 6     Hamilton   25     Great Britain    8/2/20
# 7   Verstappen   19     Great Britain    8/2/20
# 8   Verstappen   25  70th Anniversary    8/9/20
# 9     Hamilton   19  70th Anniversary    8/9/20
# 10    Hamilton   25             Spain   8/16/20
# 11  Verstappen   18             Spain   8/16/20
# 12    Hamilton   25           Belgium   8/30/20
# 13  Verstappen   15           Belgium   8/30/20
# 14    Hamilton    7             Italy    9/6/20
# 15  Verstappen    0             Italy    9/6/20
# 16    Hamilton   26           Tuscany   9/13/20
# 17  Verstappen    0           Tuscany   9/13/20
# ...

# %%
sns.lineplot(data = data, x="RaceDate", y="TotalPTS", hue = 'DriverLast')
# Out:
# <AxesSubplot:xlabel='RaceDate', ylabel='TotalPTS'>

# %%
sns.lineplot(data = data, x="Circuit", y="TotalPTS", hue = 'DriverLast')
# Out:
# <AxesSubplot:xlabel='Circuit', ylabel='TotalPTS'>

# %%
graph=sns.lineplot(
    data = data, 
    x="RaceCountry", y="TotalPTS", hue = 'DriverLast')
graph.tick_params(axis = 'x', labelrotation = 90)

# %%
graph=sns.lineplot(
    data = data, 
    x="RaceCountry", y="TotalPTS", hue = 'DriverLast',
    style = "DriverLast", markers = True, dashes = False)
graph.tick_params(axis = 'x', labelrotation = 90)

# %%
data.head()
# Out:
#    DriverLast  PTS RaceCountry RaceDate        Circuit  TotalPTS
# 0    Hamilton   12     Austria   7/5/20  Red Bull Ring        12
# 1  Verstappen    0     Austria   7/5/20  Red Bull Ring         0
# 2    Hamilton   25      Styria  7/12/20  Red Bull Ring        37
# 3  Verstappen   15      Styria  7/12/20  Red Bull Ring        15
# 4    Hamilton   26     Hungary  7/19/20    Hungaroring        63

# %%
wide_data = pd.pivot(data,index = 'RaceDate', columns = ['DriverLast'], values = 'TotalPTS')

# %%
wide_data.head()
# Out:
# DriverLast  Hamilton  Verstappen
# RaceDate
# 10/11/20       230.0       147.0
# 10/25/20       256.0       162.0
# 11/1/20        282.0       162.0
# 11/15/20       307.0       170.0
# 11/29/20       332.0       189.0

# %%
wide_data['PTSDiff']= wide_data['Hamilton']-wide_data['Verstappen']

# %%
wide_data.sort_values(by = 'RaceDate')
# Out:
# DriverLast  Hamilton  Verstappen  PTSDiff
# RaceDate
# 10/11/20       230.0       147.0     83.0
# 10/25/20       256.0       162.0     94.0
# 11/1/20        282.0       162.0    120.0
# 11/15/20       307.0       170.0    137.0
# 11/29/20       332.0       189.0    143.0
# 12/13/20       347.0       214.0    133.0
# 12/6/20          NaN       189.0      NaN
# 7/12/20         37.0        15.0     22.0
# 7/19/20         63.0        33.0     30.0
# 7/5/20          12.0         0.0     12.0
# 8/16/20        132.0        95.0     37.0
# 8/2/20          88.0        52.0     36.0
# 8/30/20        157.0       110.0     47.0
# 8/9/20         107.0        77.0     30.0
# 9/13/20        190.0       110.0     80.0
# 9/27/20        205.0       128.0     77.0
# 9/6/20         164.0       110.0     54.0

# %%
#can't have date as index. how to pivot with date column not as index but not as column values?

# %%
wide_data.reset_index(inplace=True)
wide_data.head()
# Out:
# DriverLast  RaceDate  Hamilton  Verstappen  PTSDiff
# 0           10/11/20     230.0       147.0     83.0
# 1           10/25/20     256.0       162.0     94.0
# 2            11/1/20     282.0       162.0    120.0
# 3           11/15/20     307.0       170.0    137.0
# 4           11/29/20     332.0       189.0    143.0

# %%
wide_data.sort_values(by = 'RaceDate')
# Out:
# DriverLast  RaceDate  Hamilton  Verstappen  PTSDiff
# 0           10/11/20     230.0       147.0     83.0
# 1           10/25/20     256.0       162.0     94.0
# 2            11/1/20     282.0       162.0    120.0
# 3           11/15/20     307.0       170.0    137.0
# 4           11/29/20     332.0       189.0    143.0
# 5           12/13/20     347.0       214.0    133.0
# 6            12/6/20       NaN       189.0      NaN
# 7            7/12/20      37.0        15.0     22.0
# 8            7/19/20      63.0        33.0     30.0
# 9             7/5/20      12.0         0.0     12.0
# 10           8/16/20     132.0        95.0     37.0
# 11            8/2/20      88.0        52.0     36.0
# 12           8/30/20     157.0       110.0     47.0
# 13            8/9/20     107.0        77.0     30.0
# 14           9/13/20     190.0       110.0     80.0
# 15           9/27/20     205.0       128.0     77.0
# 16            9/6/20     164.0       110.0     54.0

# %%
wide_data['RaceDate']=pd.to_datetime(wide_data['RaceDate'])
# Out:
# DriverLast   RaceDate  Hamilton  Verstappen  PTSDiff
# 0          2020-10-11     230.0       147.0     83.0
# 1          2020-10-25     256.0       162.0     94.0
# 2          2020-11-01     282.0       162.0    120.0
# 3          2020-11-15     307.0       170.0    137.0
# 4          2020-11-29     332.0       189.0    143.0
# 5          2020-12-13     347.0       214.0    133.0
# 6          2020-12-06       NaN       189.0      NaN
# 7          2020-07-12      37.0        15.0     22.0
# 8          2020-07-19      63.0        33.0     30.0
# 9          2020-07-05      12.0         0.0     12.0
# 10         2020-08-16     132.0        95.0     37.0
# 11         2020-08-02      88.0        52.0     36.0
# 12         2020-08-30     157.0       110.0     47.0
# 13         2020-08-09     107.0        77.0     30.0
# 14         2020-09-13     190.0       110.0     80.0
# 15         2020-09-27     205.0       128.0     77.0
# 16         2020-09-06     164.0       110.0     54.0

# %%
wide_data.sort_values(by = 'RaceDate')
# Out:
# DriverLast   RaceDate  Hamilton  Verstappen  PTSDiff
# 9          2020-07-05      12.0         0.0     12.0
# 7          2020-07-12      37.0        15.0     22.0
# 8          2020-07-19      63.0        33.0     30.0
# 11         2020-08-02      88.0        52.0     36.0
# 13         2020-08-09     107.0        77.0     30.0
# 10         2020-08-16     132.0        95.0     37.0
# 12         2020-08-30     157.0       110.0     47.0
# 16         2020-09-06     164.0       110.0     54.0
# 14         2020-09-13     190.0       110.0     80.0
# 15         2020-09-27     205.0       128.0     77.0
# 0          2020-10-11     230.0       147.0     83.0
# 1          2020-10-25     256.0       162.0     94.0
# 2          2020-11-01     282.0       162.0    120.0
# 3          2020-11-15     307.0       170.0    137.0
# 4          2020-11-29     332.0       189.0    143.0
# 6          2020-12-06       NaN       189.0      NaN
# 5          2020-12-13     347.0       214.0    133.0

# %%
data21 = pd.read_csv('Ham_Ver2021.csv', parse_dates = ['RaceDate'])
data21.head()
# Out:
#    Pos  DriverNo DriverFirst  DriverLast DriverAbv                   Team  \
# 0    1        44       Lewis    Hamilton       HAM               Mercedes
# 1    2        33         Max  Verstappen       VER  Red Bull Racing Honda
# 2    1        33         Max  Verstappen       VER  Red Bull Racing Honda
# 3    2        44       Lewis    Hamilton       HAM               Mercedes
# 4    1        44       Lewis    Hamilton       HAM               Mercedes
#
#    Laps Retired   PTS     RaceCountry   RaceDate  \
# 0    56       0  25.0         Bahrain 2021-03-28
# 1    56       0  18.0         Bahrain 2021-03-28
# 2    63       0  25.0  Emilia Romagna 2021-04-18
# 3    63       0  19.0  Emilia Romagna 2021-04-18
# 4    66       0  25.0        Portugal 2021-05-02
#
#                               Circuit  RaceCity
# 0       Bahrain International Circuit    Sakhir
# 1       Bahrain International Circuit    Sakhir
# 2       Autodromo Enzo e Dino Ferrari     Imola
# ...

# %%
Ham_Ver21 = data21[['DriverLast', 'PTS', 'RaceCountry', 'RaceDate']]
Ham_Ver21.head()
# Out:
#    DriverLast   PTS     RaceCountry   RaceDate
# 0    Hamilton  25.0         Bahrain 2021-03-28
# 1  Verstappen  18.0         Bahrain 2021-03-28
# 2  Verstappen  25.0  Emilia Romagna 2021-04-18
# 3    Hamilton  19.0  Emilia Romagna 2021-04-18
# 4    Hamilton  25.0        Portugal 2021-05-02

# %%
#combine 3 plots in one figure? points score, cumsum points, diff points

# %%
Ham_Ver21.sort_values(by = 'RaceDate')
Ham_Ver21['TotalPTS'] = Ham_Ver21.groupby(['DriverLast'])['PTS'].cumsum()
Ham_Ver21
# Out:
# <ipython-input-5-479c6ba88178>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ham_Ver21['TotalPTS'] = Ham_Ver21.groupby(['DriverLast'])['PTS'].cumsum()
#     DriverLast   PTS     RaceCountry   RaceDate  TotalPTS
# 0     Hamilton  25.0         Bahrain 2021-03-28      25.0
# 1   Verstappen  18.0         Bahrain 2021-03-28      18.0
# 2   Verstappen  25.0  Emilia Romagna 2021-04-18      43.0
# 3     Hamilton  19.0  Emilia Romagna 2021-04-18      44.0
# 4     Hamilton  25.0        Portugal 2021-05-02      69.0
# 5   Verstappen  18.0        Portugal 2021-05-02      61.0
# 6     Hamilton  25.0           Spain 2021-05-09      94.0
# 7   Verstappen  19.0           Spain 2021-05-09      80.0
# ...

# %%
fig,axes = plt.subplots(1,2,figsize=(15,5), sharex=True)
fig.suptitle('2021 Drivers Champ Battle')

g1 = sns.lineplot(data = Ham_Ver21, x="RaceCountry", y="PTS", hue = 'DriverLast', ax=axes[0])
g1.tick_params(axis = 'x', labelrotation = 90)

g2 = sns.lineplot(data = Ham_Ver21, x="RaceCountry", y="TotalPTS", hue = 'DriverLast',ax = axes[1])
g2.tick_params(axis = 'x', labelrotation = 90)

# %%
#add difference graph, add anotations, change colors?

# %%
wide_21 = pd.pivot(Ham_Ver21,index = ['RaceDate', 'RaceCountry'], columns = ['DriverLast'], values = 'TotalPTS')
wide_21['PTSDiff']= wide_21['Hamilton']-wide_21['Verstappen']
wide_21.head()
# Out:
# DriverLast                 Hamilton  Verstappen  PTSDiff
# RaceDate   RaceCountry
# 2021-03-28 Bahrain             25.0        18.0      7.0
# 2021-04-18 Emilia Romagna      44.0        43.0      1.0
# 2021-05-02 Portugal            69.0        61.0      8.0
# 2021-05-09 Spain               94.0        80.0     14.0
# 2021-05-23 Monaco             101.0       105.0     -4.0

# %%
wide_21.reset_index(inplace=True)
wide_21.head()
# Out:
# DriverLast   RaceDate     RaceCountry  Hamilton  Verstappen  PTSDiff
# 0          2021-03-28         Bahrain      25.0        18.0      7.0
# 1          2021-04-18  Emilia Romagna      44.0        43.0      1.0
# 2          2021-05-02        Portugal      69.0        61.0      8.0
# 3          2021-05-09           Spain      94.0        80.0     14.0
# 4          2021-05-23          Monaco     101.0       105.0     -4.0

# %%
g3 = sns.lineplot(data = wide_21, x = 'RaceCountry', y='PTSDiff')
g3.tick_params(axis = 'x', labelrotation = 90)
plt.ylim(-35,35)
#ax.set(ylim=(-35,35))
# Out:
# (-35.0, 35.0)

# %%
fig, axes = plt.subplots()

g3 = sns.lineplot(data = wide_21, x = 'RaceCountry', y='PTSDiff', ax = axes, color = 'black')

#ax.plot(x, y, 'k')
#ax.grid()
#ax.margins(0) # remove default margins (matplotlib verision 2+)

g3.tick_params(axis = 'x', labelrotation = 90)
plt.ylim(-35,35)

axes.axhspan(0, 35, facecolor='blue', alpha=0.3)
axes.axhspan(-35, 0, facecolor='orange', alpha=0.3)
#ax.axhspan(9, 12, facecolor='red', alpha=0.5)

#plt.show()
